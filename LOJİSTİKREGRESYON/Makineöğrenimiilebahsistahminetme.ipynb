# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt     
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression  
from sklearn.metrics import mean_squared_error

# %%
veri=sns.load_dataset('tips')             #Veri seti yüklenir.

# %%
new_datasheet=veri.drop(['sex','size','time','day','smoker'],axis=1)
new_datasheet.head()                      #Veri setinden kullanılmayacak özellikler silinir.
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
m= len(new_datasheet) 
X=np.reshape(np.asarray(new_datasheet['total_bill']), (m,-1))
y=np.reshape(np.asarray(new_datasheet['tip']), (m , - 1))
#Özellikler  vektör haline dönüştürülür.

# %%
X ,y
# Out:
# (array([[16.99],
#         [10.34],
#         [21.01],
#         [23.68],
#         [24.59],
#         [25.29],
#         [ 8.77],
#         [26.88],
#         [15.04],
#         [14.78],
#         [10.27],
#         [35.26],
#         [15.42],
#         [18.43],
#         [14.83],
#         [21.58],
#         [10.33],
#         [16.29],
#         [16.97],
#         [20.65],
#         [17.92],
#         [20.29],
#         [15.77],
#         [39.42],
#         [19.82],
#         [17.81],
#         [13.37],
#         [12.69],
#         [21.7 ],
#         [19.65],
#         [ 9.55],
#         [18.35],
#         [15.06],
#         [20.69],
#         [17.78],
#         [24.06],
#         [16.31],
#         [16.93],
#         [18.69],
#         [31.27],
#         [16.04],
#         [17.46],
#         [13.94],
#         [ 9.68],
#         [30.4 ],
#         [18.29],
#         [22.23],
#         [32.4 ],
#         [28.55],
#         [18.04],
#         [12.54],
#         [10.29],
# ...

# %%
X_train , X_test, y_train, y_test= train_test_split(X,y,test_size=0.2)

# %%
model= LinearRegression()
model.fit(X,y)
y_pred=model.predict(X_test)   #X test verileri üzerinden test yapılır.

# %%
MSE=mean_squared_error(y_test,y_pred)
MSE    # Gerçek değerlerle tahmin edilen değerler arasındaki hata miktarını hesaplanır.
# Out:
# 0.9398354033724227

# %%
#Modelin grafik oluşumu
plt.scatter(X_test,y_test ,edgecolors='green',c='blue')
plt.plot(X_test,y_pred,c='pink',zorder=1)
plt.xlabel('Hesap')
plt.ylabel('Bahsis')
plt.title('Ödeme tutarına göre bahşiş miktarı')
plt.show()

# %%
#26.5 lira hesap ödeyen kadının verebileceği tahmini bahşiş miktarı
veri=sns.load_dataset('tips')
new_datasheet = veri.copy()
new_datasheet=new_datasheet[new_datasheet['sex'] == 'Female']      #Sadece cinsiyeti kadın olanlar seçilir.
new_datasheet.head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
new_datasheet=veri.drop(['sex','size','time','day','smoker'],axis=1)
new_datasheet.head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
m=len(new_datasheet)

# %%
X=np.reshape(np.asarray(new_datasheet['total_bill']),(m,-1))
y=np.reshape(np.asarray(new_datasheet['tip']),(m,-1))
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2 ,random_state=False)

# %%
model= LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
MSEK=mean_squared_error(y_test,y_pred)
MSEK
# Out:
# 0.9010493952697899

# %%
tahmini_bahsis = model.predict(np.array([[26.5]]))
tahmini_bahsis
# Out:
# array([[3.46994794]])

# %%
plt.scatter(X_test,y_test,edgecolors='black' , c='yellow')
plt.plot(X_test ,y_pred ,c ='purple')
plt.xlabel('Hesap')
plt.ylabel('Bahşiş')
plt.title('26.5 lira hesap ödeyen kadının verebileceği tahmini bahşiş miktarı')
plt.show()
